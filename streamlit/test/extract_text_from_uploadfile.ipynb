# %%
content = """
웹 개발에 관심이 많은 신입 개발자입니다. (안강현 - 이력서) 안강현남2000년 (만 25세) 010-9935-6425 휴대폰 ahn1816@na ver.com Email 서울 서대문구 창천동 주소 학력 명지전문대학 대학(2,3년) 졸업경력 대리 / 해외경험 -자격증 / 어학 정보처리산업기사 외 1 JAVA Spring Boot JPA API Spring MySQL Git AWS 노력 끈기 Python SQL AWS EC2 학력 컴퓨터공학과 2019 . 03 ~ 202 4. 02 졸업명지전문대학 3.96 / 4 .5 학점 자격증 한국산업인력공단 2024. 09 정보처리산업기사 한국데이터산업진흥원 2022. 12 SQL 개발자 자기소개서 수많은 직업 중, 왜 프로그래머인가? 프로그래밍을 처음 접했던 순간부터, 제가 개발한 프로그램이 실제도 동작하는 모습을 보며 큰 즐거움과 성취감을 느꼈습니다. 단순히 기능 구현에 그치는 것이 아니라, 직접 만든 프로그램이 사용자들에게 실질적인 가치를 제공하는 경험을 쌓아가면서 프로그래머라는 직업을 꿈꾸게 되었습니다. 그 중에서도 저는 웹 개발과 서비스 구축에 큰 매력을 느꼈습니다. 기능을 단순히 구현하는 것을 넘어, 사용자에게 실질적인 가치를 전달하는 웹 서비스를 기획하 고 설계하며 완성해가는 과정에서 큰 재미와 몰입감을 경험했습니다. 웹 서비스 개발 경험 후쿠오카 맛집 지도 프로젝트에서 Ja va, Spring Boot, Spring Data JP A 기반 RESTful API 기반API 서버를 설계 및 구현했습니다. 또한 모바일과 데스크탑 환경 모두에서 사용 가능한 반응형 프론트엔드(R eact + T ypeScript)와 연동하였고, AWS의 RDS, S3, EC2, Cloud F ront, ELB 서비스를 활용하여 배포를 완 료했습니다. 이 과정에서 HTTPS와 HTTP 간의 Mix ed Cont ent 문제, ORM 연관 관계 설정의 어려움 등을 겪었으며, AWS 로드 밸런서 설정 및 자체 데이터 입력 툴 개발 을 통해 안정정인 웹 서비스 운영이 가능하도록 개선했습니다. 25. 7. 17. 오후 2:47 이력서 인쇄하기 https://www.jobkorea.co.kr/User/Resume/Print?RNo=28405139 1/3 위의 모든 기재사항은 사실과 다름없음을 확인합니다. 작성자 : 안강현 이 이력서는 2025년 05월 01일 (목)에 최종 수정된 이력서 입니다. 위조된 문서를 등록하여 취업활동에 이용 시 법적 책임을 지게 될 수 있습니다. 잡코리아(유)는 구직자가 등록 한 문서에 대해 보증하거나 별도의 책임을 지지 않으며프로그래머로서의 강점과 단점 저는 문제 해결 능력과 높은 과제 집중도를 강점으로 삼고 있습니다. 예를 들어, 유명 커뮤니티 사이트의 인기 게시글을 자동으로 스크래핑하여 특정 애플리케이션에 업로드하는 프로젝트를 진행한 적이 있습니다. 일반적인 스크래 핑 방식으로는 원본 게시글의 스타일(폰트 스타일, 이미지 배치)을 유지하기 어려웠고, 이를 해결하기 위해 화면을 캡처해 이미지로 저장하여 업로드하는 방식을 적용했습니다. 이 접근 방식 덕분에 원본 게시글의 형태를 유지하면서도 효과적으로 애플리케이션에 게시할 수 있었고, 프로젝트를 의뢰한 운영사에서도 높은 만 족도를 보였습니다. 또한, 앞서 언급한 후쿠오카 맛집 지도 프로젝트에서도 CORS 및 Mix ed Cont ent 문제 등 다양한 문제들을 해결하며, 웹 개발과 배포 과정에서의 기술적 역량 과 문제 해결 능력을 키웠습니다. 한편, 저는 결과 중심적인 성향이 강해 새로운 개념을 깊이 탐구하기보다 빠른 해결에 집중하는 경향이 있습니다. 하지만 이를 보완하기 위해, 프로젝트를 진행할 때마다 발생하는 문제를 정리하고, 기술적 개념을 더욱 깊이 이해하려 노력하고 있습니다. 입사 후 포부 아이코닉무브먼트의 D X사업개발실은 실감형 콘텐츠 제작 경험과 기술적 노하우를 바탕으로, 콘텐츠 제작과 운영 전반을 아우르는 통합 시스템을 개발하는 것을 목표로 하고 있습니다. 저는 웹 서비스 개발과 다양한 문제 해결 경험을 통해, 이러한 방향성과 잘 맞는 역량을 갖추었다고 생각합니다. 특히, 후쿠오카 맛집 지도 프로젝트에서 R eact와 Ja va(Spring Boot)를 기반으로 RESTful API 설계와 구축, 클라이언트와의 연동, 그리고 A WS 인프라를 활용한 서비스 배포까지 전 과정을 혼자 경험하였습니다. 이를 통해 콘텐츠 중심의 서비스를 구조화하고, 안정적으로 운영할 수 있는 기술적 기반을 익혔습니다. 또한 외주 프로젝트를 통해 커뮤니티 콘텐츠를 수집·재가공하고, 애플리케이션에 자동 업로드하는 프로그램을 구현한 경험은, 콘텐츠 제작-운영간의 효율성을 높 이기 위한 통합 시스템 개발이라는 D X사업개발실의 목표에 직접적으로 기여할 수 있는 부분이라 생각하비낟. 입사 후에는 아이코닉무브먼트의 기술적 비전과 예술적 감성을 이어주는 개발자가 되어, 실감형 콘텐츠 제작과 운영을 뒷받침할 수 있는 유연하고 확장성 있는 시 스템 설계 및 구현에 주도적으로 참여하겠습니다. 사용자 경험을 고려한 기술 설계, 안정적인 서비스 운영을 팀원들과 같이 주도하는 팀의 일원, 아이코닉무브먼 트의 새로운 아이콘이 되고 싶습니다. 포트폴리오 포트폴리오 포트폴리오 안강현_P ortfolio.pdf https://fier ce-helium-a6e.notion.sit e/Port… 취업우대사항 보훈대상 여부 - 취업보호대상 여부 - 고용지원금대상 여부 - 병역사항 [군필] 2020 . 05 ~ 2021 . 11 육군 병장 제대 장애여부 - 희망근무조건 희망근무지 서울전지역 희망연봉 면접 후 결정 지원분야직무 백엔드개발자 >서버관리, 클라이언트 산업 솔루션·SI·CRM·ERP >모바일앱개발, 소프트웨어개발25. 7. 17. 오후 2:47 이력서 인쇄하기 https://www.jobkorea.co.kr/User/Resume/Print?RNo=28405139 2/3 첨부된 문서를 신뢰하여 발생한 법적 분쟁에 책임을 지지 않습니다. 또한 구인/구직 목적 외 다른 목적으로 이용시 이력서 삭제 혹은 비공개 조치가 될 수 있습니다. 인쇄번호 : 6f9e557 4f22af dc525. 7. 17. 오후 2:47 이력서 인쇄하기 https://www.jobkorea.co.kr/User/Resume/Print?RNo=28405139 3/3
"""

# %%
import os
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.schema.runnable import RunnableLambda
api_key = os.environ.get("OPENAI_API_KEY")

model = ChatOpenAI(
    model='gpt-4.1',
    temperature=0.1,
)

response_schemas = [
    ResponseSchema(name="학력", description="최종 학력과 졸업 여부를 포함한 정보 (예: 전문학사 졸업)"),
    ResponseSchema(name="학력수치", description="학력을 숫자로 표현 (전문학사=0, 학사=1, 석사=2, 박사=3, 무관=-1, 고졸=-2)"),
    ResponseSchema(name="학과", description="전공한 학과명 (예: 컴퓨터공학과)"),
    ResponseSchema(name="경력", description="경력 요약 (예: 3년차, 대리, 5년차, 신입) 및 인턴·대외활동 여부 명시"),
    ResponseSchema(name="경력수치", description="경력을 숫자로 표현. 신입=0, 1년차=1, 2년차=2, …, 대리=3, 과장=5, 차장=8, 무관=-1"),
    ResponseSchema(name="자격증", description="보유 자격증명과 취득 시기 (예: 정보처리산업기사 2024.09)"),
    ResponseSchema(name="보유스킬", description="보유 기술 스택 목록 (예: Java, Spring Boot, JPA, MySQL 등)"),
    ResponseSchema(name="자기소개서", description="자기소개서 전체 내용")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
format_instructions = output_parser.get_format_instructions()


prompt = ChatPromptTemplate.from_template(
    """
    너는 이력서에서 경력, 학과, 학력, 자격증, 보유스킬, 자기소개서 내용을 추출하는 전문가야.

    경력수치는 아래 기준으로 변환해.
    - 신입은 0
    - 1년차는 1
    - 2년차는 2
    - 3년차는 3
    - 4년차는 4 … 경력 연차에 맞춰 숫자를 그대로 사용해
    - 직급으로 표현된 경우 (대리=3, 과장=5, 차장=8)
    - 무관은 -1로 처리해

    숫자화된 학력과 경력 정보를 포함해서 JSON으로 변환해줘.

    {format_instructions}

    이력서 본문:
    \"\"\"
    {content}
    \"\"\"
    """
)

chain = (
    prompt
    | model
    | RunnableLambda(lambda x: output_parser.parse(x.content))
)

result = chain.invoke({
    "format_instructions" : format_instructions,
    "content" : content
})

result
# Out:
# {'학력': '명지전문대학 컴퓨터공학과 전문학사 졸업',
#  '학력수치': '0',
#  '학과': '컴퓨터공학과',
#  '경력': '대리 (정규직), 인턴·대외활동 없음',
#  '경력수치': '3',
#  '자격증': '정보처리산업기사 2024.09, SQL 개발자 2022.12',
#  '보유스킬': 'Java, Spring Boot, JPA, API, Spring, MySQL, Git, AWS, Python, SQL, AWS EC2, React, TypeScript, AWS RDS, AWS S3, AWS CloudFront, AWS ELB',
# ...
